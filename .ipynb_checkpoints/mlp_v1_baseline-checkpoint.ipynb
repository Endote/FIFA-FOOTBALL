# %%
import pandas as pd
import torch
import torch.nn as nn

from torch.utils.data import TensorDataset, DataLoader
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.metrics import roc_auc_score

# %%
train = pd.read_csv("data/baseline_modeling/baseline_train_model_ready.csv")
val = pd.read_csv("data/baseline_modeling/baseline_val_model_ready.csv")
test = pd.read_csv("data/baseline_modeling/baseline_test_model_ready.csv")

# %%
import numpy as np
import pandas as pd

def preprocess_df(df):
    new_df = df.copy()

    # --- 1. drop columns
    new_df = new_df.drop(columns=['date', 'jersey_number'], errors='ignore')

    # --- 2. drop checkpoint columns
    new_df = new_df.drop(columns=['checkpoint_period', 'checkpoint_min'], errors='ignore')

    # --- 3. create minutes_in_game
    new_df['minutes_in_game'] = new_df['minute_out'] - new_df['minute_in']

    # drop old columns
    new_df = new_df.drop(columns=['minute_in', 'minute_out'], errors='ignore')

    # --- 4. filtering
    new_df = new_df[
        (new_df['last15_distance'] <= 1000) &
        (new_df['cumul_peak_speed'] <= 10.3)
    ]

    return new_df.reset_index(drop=True)

# %%
train = preprocess_df(train)
val   = preprocess_df(val)
test  = preprocess_df(test)

# %%
target = "scored_after"

X_vars = train.drop(columns=target).columns.to_list()

cat_cols = train[X_vars].select_dtypes(include=["object", "category", "string"]).columns.to_list()
num_cols = train[X_vars].select_dtypes(include=["number", "bool"]).columns.to_list()

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), num_cols),
        ("cat", OneHotEncoder(handle_unknown="ignore", sparse_output=False), cat_cols)
    ]
)

X_train_np = preprocessor.fit_transform(train[X_vars])
X_val_np = preprocessor.transform(val[X_vars])

y_train_np = train[target].to_numpy()
y_val_np = val[target].to_numpy()

# %%
X_train = torch.tensor(X_train_np, dtype=torch.float32)
y_train = torch.tensor(y_train_np, dtype=torch.float32).view(-1, 1)

X_val = torch.tensor(X_val_np, dtype=torch.float32)
y_val = torch.tensor(y_val_np, dtype=torch.float32).view(-1, 1)

train_ds = TensorDataset(X_train, y_train)
val_ds = TensorDataset(X_val, y_val)

train_loader = DataLoader(train_ds, batch_size=64, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=256, shuffle=False)

# %%
class MLP(nn.Module):
    def __init__(self, input_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Dropout(0.2),

            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.2),

            nn.Linear(64, 1)
        )

    def forward(self, x):
        return self.net(x)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = MLP(input_dim=X_train.shape[1]).to(device)
criterion = nn.BCEWithLogitsLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# %%
def evaluate_model(model, data_loader, criterion, device):
    model.eval()
    total_loss = 0.0
    all_probs = []
    all_y = []

    with torch.no_grad():
        for X_batch, y_batch in data_loader:
            X_batch = X_batch.to(device)
            y_batch = y_batch.to(device)

            logits = model(X_batch)
            loss = criterion(logits, y_batch)

            total_loss += loss.item() * X_batch.size(0)

            probs = torch.sigmoid(logits)
            all_probs.append(probs.cpu())
            all_y.append(y_batch.cpu())

    all_probs = torch.cat(all_probs).numpy().ravel()
    all_y = torch.cat(all_y).numpy().ravel()

    avg_loss = total_loss / len(data_loader.dataset)
    auc = roc_auc_score(all_y, all_probs)
    preds = (all_probs >= 0.5).astype(int)
    acc = (preds == all_y).mean()

    return avg_loss, acc, auc

# %%
n_epochs = 100

for epoch in range(n_epochs):
    model.train()
    train_loss_sum = 0.0

    for X_batch, y_batch in train_loader:
        X_batch = X_batch.to(device)
        y_batch = y_batch.to(device)

        optimizer.zero_grad()
        logits = model(X_batch)
        loss = criterion(logits, y_batch)
        loss.backward()
        optimizer.step()

        train_loss_sum += loss.item() * X_batch.size(0)

    train_loss = train_loss_sum / len(train_loader.dataset)
    val_loss, val_acc, val_auc = evaluate_model(model, val_loader, criterion, device)

    print(
        f"Epoch {epoch+1:02d}/{n_epochs} | "
        f"Train Loss: {train_loss:.4f} | "
        f"Val Loss: {val_loss:.4f} | "
        f"Val Acc: {val_acc:.4f} | "
        f"Val ROC AUC: {val_auc:.4f}"
    )
# Out:
# Epoch 01/100 | Train Loss: 0.3972 | Val Loss: 0.2092 | Val Acc: 0.9490 | Val ROC AUC: 0.5286
# Epoch 02/100 | Train Loss: 0.2251 | Val Loss: 0.1970 | Val Acc: 0.9490 | Val ROC AUC: 0.6144
# Epoch 03/100 | Train Loss: 0.2173 | Val Loss: 0.2024 | Val Acc: 0.9490 | Val ROC AUC: 0.6010
# Epoch 04/100 | Train Loss: 0.2100 | Val Loss: 0.2033 | Val Acc: 0.9490 | Val ROC AUC: 0.6213
# Epoch 05/100 | Train Loss: 0.2015 | Val Loss: 0.2015 | Val Acc: 0.9490 | Val ROC AUC: 0.6072
# Epoch 06/100 | Train Loss: 0.2004 | Val Loss: 0.2016 | Val Acc: 0.9490 | Val ROC AUC: 0.6056
# Epoch 07/100 | Train Loss: 0.1995 | Val Loss: 0.2036 | Val Acc: 0.9490 | Val ROC AUC: 0.6065
# Epoch 08/100 | Train Loss: 0.1934 | Val Loss: 0.1985 | Val Acc: 0.9490 | Val ROC AUC: 0.6197
# Epoch 09/100 | Train Loss: 0.1929 | Val Loss: 0.1986 | Val Acc: 0.9490 | Val ROC AUC: 0.6242
# Epoch 10/100 | Train Loss: 0.1895 | Val Loss: 0.2032 | Val Acc: 0.9490 | Val ROC AUC: 0.6258
# Epoch 11/100 | Train Loss: 0.1838 | Val Loss: 0.2057 | Val Acc: 0.9490 | Val ROC AUC: 0.6081
# Epoch 12/100 | Train Loss: 0.1777 | Val Loss: 0.2053 | Val Acc: 0.9490 | Val ROC AUC: 0.6180
# Epoch 13/100 | Train Loss: 0.1751 | Val Loss: 0.2072 | Val Acc: 0.9490 | Val ROC AUC: 0.6146
# Epoch 14/100 | Train Loss: 0.1728 | Val Loss: 0.2110 | Val Acc: 0.9490 | Val ROC AUC: 0.6036
# Epoch 15/100 | Train Loss: 0.1706 | Val Loss: 0.2146 | Val Acc: 0.9490 | Val ROC AUC: 0.6112
# Epoch 16/100 | Train Loss: 0.1673 | Val Loss: 0.2121 | Val Acc: 0.9474 | Val ROC AUC: 0.6247
# Epoch 17/100 | Train Loss: 0.1645 | Val Loss: 0.2138 | Val Acc: 0.9490 | Val ROC AUC: 0.6253
# Epoch 18/100 | Train Loss: 0.1572 | Val Loss: 0.2187 | Val Acc: 0.9474 | Val ROC AUC: 0.6124
# Epoch 19/100 | Train Loss: 0.1522 | Val Loss: 0.2143 | Val Acc: 0.9474 | Val ROC AUC: 0.6358
# Epoch 20/100 | Train Loss: 0.1497 | Val Loss: 0.2244 | Val Acc: 0.9490 | Val ROC AUC: 0.6247
# Epoch 21/100 | Train Loss: 0.1452 | Val Loss: 0.2184 | Val Acc: 0.9490 | Val ROC AUC: 0.6415
# Epoch 22/100 | Train Loss: 0.1471 | Val Loss: 0.2276 | Val Acc: 0.9474 | Val ROC AUC: 0.6248
# Epoch 23/100 | Train Loss: 0.1381 | Val Loss: 0.2211 | Val Acc: 0.9459 | Val ROC AUC: 0.6492
# Epoch 24/100 | Train Loss: 0.1351 | Val Loss: 0.2284 | Val Acc: 0.9490 | Val ROC AUC: 0.6431
# Epoch 25/100 | Train Loss: 0.1267 | Val Loss: 0.2290 | Val Acc: 0.9459 | Val ROC AUC: 0.6517
# Epoch 26/100 | Train Loss: 0.1235 | Val Loss: 0.2381 | Val Acc: 0.9413 | Val ROC AUC: 0.6440
# Epoch 27/100 | Train Loss: 0.1294 | Val Loss: 0.2403 | Val Acc: 0.9428 | Val ROC AUC: 0.6505
# Epoch 28/100 | Train Loss: 0.1169 | Val Loss: 0.2421 | Val Acc: 0.9413 | Val ROC AUC: 0.6531
# Epoch 29/100 | Train Loss: 0.1148 | Val Loss: 0.2430 | Val Acc: 0.9428 | Val ROC AUC: 0.6634
# Epoch 30/100 | Train Loss: 0.1101 | Val Loss: 0.2535 | Val Acc: 0.9444 | Val ROC AUC: 0.6500
# Epoch 31/100 | Train Loss: 0.1121 | Val Loss: 0.2559 | Val Acc: 0.9335 | Val ROC AUC: 0.6624
# Epoch 32/100 | Train Loss: 0.0996 | Val Loss: 0.2617 | Val Acc: 0.9444 | Val ROC AUC: 0.6545
# Epoch 33/100 | Train Loss: 0.1028 | Val Loss: 0.2786 | Val Acc: 0.9413 | Val ROC AUC: 0.6414
# Epoch 34/100 | Train Loss: 0.1008 | Val Loss: 0.2808 | Val Acc: 0.9428 | Val ROC AUC: 0.6461
# Epoch 35/100 | Train Loss: 0.0981 | Val Loss: 0.2766 | Val Acc: 0.9428 | Val ROC AUC: 0.6570
# Epoch 36/100 | Train Loss: 0.1004 | Val Loss: 0.2835 | Val Acc: 0.9459 | Val ROC AUC: 0.6605
# Epoch 37/100 | Train Loss: 0.0949 | Val Loss: 0.2812 | Val Acc: 0.9413 | Val ROC AUC: 0.6592
# Epoch 38/100 | Train Loss: 0.0971 | Val Loss: 0.2753 | Val Acc: 0.9444 | Val ROC AUC: 0.6745
# Epoch 39/100 | Train Loss: 0.0844 | Val Loss: 0.2969 | Val Acc: 0.9382 | Val ROC AUC: 0.6566
# Epoch 40/100 | Train Loss: 0.0855 | Val Loss: 0.2902 | Val Acc: 0.9382 | Val ROC AUC: 0.6698
# Epoch 41/100 | Train Loss: 0.0869 | Val Loss: 0.3074 | Val Acc: 0.9335 | Val ROC AUC: 0.6593
# Epoch 42/100 | Train Loss: 0.0892 | Val Loss: 0.3064 | Val Acc: 0.9351 | Val ROC AUC: 0.6584
# Epoch 43/100 | Train Loss: 0.0759 | Val Loss: 0.3023 | Val Acc: 0.9397 | Val ROC AUC: 0.6726
# Epoch 44/100 | Train Loss: 0.0724 | Val Loss: 0.3149 | Val Acc: 0.9428 | Val ROC AUC: 0.6663
# Epoch 45/100 | Train Loss: 0.0785 | Val Loss: 0.3108 | Val Acc: 0.9397 | Val ROC AUC: 0.6711
# Epoch 46/100 | Train Loss: 0.0805 | Val Loss: 0.3155 | Val Acc: 0.9397 | Val ROC AUC: 0.6698
# Epoch 47/100 | Train Loss: 0.0739 | Val Loss: 0.3251 | Val Acc: 0.9397 | Val ROC AUC: 0.6624
# Epoch 48/100 | Train Loss: 0.0685 | Val Loss: 0.3453 | Val Acc: 0.9428 | Val ROC AUC: 0.6594
# Epoch 49/100 | Train Loss: 0.0707 | Val Loss: 0.3419 | Val Acc: 0.9366 | Val ROC AUC: 0.6680
# Epoch 50/100 | Train Loss: 0.0676 | Val Loss: 0.3327 | Val Acc: 0.9335 | Val ROC AUC: 0.6740
# Epoch 51/100 | Train Loss: 0.0704 | Val Loss: 0.3339 | Val Acc: 0.9444 | Val ROC AUC: 0.6742
# Epoch 52/100 | Train Loss: 0.0627 | Val Loss: 0.3557 | Val Acc: 0.9444 | Val ROC AUC: 0.6734
# Epoch 53/100 | Train Loss: 0.0628 | Val Loss: 0.3532 | Val Acc: 0.9413 | Val ROC AUC: 0.6637
# Epoch 54/100 | Train Loss: 0.0635 | Val Loss: 0.3789 | Val Acc: 0.9397 | Val ROC AUC: 0.6535
# Epoch 55/100 | Train Loss: 0.0642 | Val Loss: 0.3604 | Val Acc: 0.9413 | Val ROC AUC: 0.6763
# Epoch 56/100 | Train Loss: 0.0579 | Val Loss: 0.3783 | Val Acc: 0.9397 | Val ROC AUC: 0.6645
# Epoch 57/100 | Train Loss: 0.0677 | Val Loss: 0.3735 | Val Acc: 0.9382 | Val ROC AUC: 0.6680
# Epoch 58/100 | Train Loss: 0.0604 | Val Loss: 0.3833 | Val Acc: 0.9397 | Val ROC AUC: 0.6734
# Epoch 59/100 | Train Loss: 0.0583 | Val Loss: 0.3773 | Val Acc: 0.9382 | Val ROC AUC: 0.6778
# Epoch 60/100 | Train Loss: 0.0603 | Val Loss: 0.3972 | Val Acc: 0.9351 | Val ROC AUC: 0.6700
# Epoch 61/100 | Train Loss: 0.0621 | Val Loss: 0.3922 | Val Acc: 0.9351 | Val ROC AUC: 0.6680
# Epoch 62/100 | Train Loss: 0.0563 | Val Loss: 0.3936 | Val Acc: 0.9413 | Val ROC AUC: 0.6633
# Epoch 63/100 | Train Loss: 0.0544 | Val Loss: 0.4199 | Val Acc: 0.9397 | Val ROC AUC: 0.6529
# Epoch 64/100 | Train Loss: 0.0543 | Val Loss: 0.4180 | Val Acc: 0.9382 | Val ROC AUC: 0.6616
# Epoch 65/100 | Train Loss: 0.0538 | Val Loss: 0.4251 | Val Acc: 0.9428 | Val ROC AUC: 0.6601
# Epoch 66/100 | Train Loss: 0.0503 | Val Loss: 0.4138 | Val Acc: 0.9413 | Val ROC AUC: 0.6638
# Epoch 67/100 | Train Loss: 0.0530 | Val Loss: 0.4051 | Val Acc: 0.9382 | Val ROC AUC: 0.6797
# Epoch 68/100 | Train Loss: 0.0477 | Val Loss: 0.4331 | Val Acc: 0.9444 | Val ROC AUC: 0.6649
# Epoch 69/100 | Train Loss: 0.0519 | Val Loss: 0.4276 | Val Acc: 0.9428 | Val ROC AUC: 0.6747
# Epoch 70/100 | Train Loss: 0.0464 | Val Loss: 0.4372 | Val Acc: 0.9428 | Val ROC AUC: 0.6676
# Epoch 71/100 | Train Loss: 0.0493 | Val Loss: 0.4291 | Val Acc: 0.9459 | Val ROC AUC: 0.6834
# Epoch 72/100 | Train Loss: 0.0388 | Val Loss: 0.4382 | Val Acc: 0.9413 | Val ROC AUC: 0.6794
# Epoch 73/100 | Train Loss: 0.0426 | Val Loss: 0.4583 | Val Acc: 0.9428 | Val ROC AUC: 0.6698
# Epoch 74/100 | Train Loss: 0.0482 | Val Loss: 0.4571 | Val Acc: 0.9397 | Val ROC AUC: 0.6645
# Epoch 75/100 | Train Loss: 0.0533 | Val Loss: 0.4472 | Val Acc: 0.9413 | Val ROC AUC: 0.6802
# Epoch 76/100 | Train Loss: 0.0463 | Val Loss: 0.4660 | Val Acc: 0.9428 | Val ROC AUC: 0.6687
# Epoch 77/100 | Train Loss: 0.0455 | Val Loss: 0.4606 | Val Acc: 0.9366 | Val ROC AUC: 0.6709
# Epoch 78/100 | Train Loss: 0.0424 | Val Loss: 0.4831 | Val Acc: 0.9382 | Val ROC AUC: 0.6594
# Epoch 79/100 | Train Loss: 0.0418 | Val Loss: 0.4704 | Val Acc: 0.9413 | Val ROC AUC: 0.6719
# Epoch 80/100 | Train Loss: 0.0363 | Val Loss: 0.4787 | Val Acc: 0.9444 | Val ROC AUC: 0.6726
# Epoch 81/100 | Train Loss: 0.0413 | Val Loss: 0.5141 | Val Acc: 0.9444 | Val ROC AUC: 0.6690
# Epoch 82/100 | Train Loss: 0.0431 | Val Loss: 0.4818 | Val Acc: 0.9459 | Val ROC AUC: 0.6796
# Epoch 83/100 | Train Loss: 0.0404 | Val Loss: 0.4947 | Val Acc: 0.9428 | Val ROC AUC: 0.6699
# Epoch 84/100 | Train Loss: 0.0354 | Val Loss: 0.5111 | Val Acc: 0.9428 | Val ROC AUC: 0.6611
# Epoch 85/100 | Train Loss: 0.0374 | Val Loss: 0.5032 | Val Acc: 0.9351 | Val ROC AUC: 0.6672
# Epoch 86/100 | Train Loss: 0.0379 | Val Loss: 0.4954 | Val Acc: 0.9459 | Val ROC AUC: 0.6752
# Epoch 87/100 | Train Loss: 0.0351 | Val Loss: 0.4933 | Val Acc: 0.9459 | Val ROC AUC: 0.6880
# Epoch 88/100 | Train Loss: 0.0344 | Val Loss: 0.5168 | Val Acc: 0.9397 | Val ROC AUC: 0.6737
# Epoch 89/100 | Train Loss: 0.0317 | Val Loss: 0.5047 | Val Acc: 0.9413 | Val ROC AUC: 0.6839
# Epoch 90/100 | Train Loss: 0.0377 | Val Loss: 0.5372 | Val Acc: 0.9351 | Val ROC AUC: 0.6680
# Epoch 91/100 | Train Loss: 0.0390 | Val Loss: 0.5373 | Val Acc: 0.9413 | Val ROC AUC: 0.6634
# Epoch 92/100 | Train Loss: 0.0345 | Val Loss: 0.5370 | Val Acc: 0.9382 | Val ROC AUC: 0.6630
# Epoch 93/100 | Train Loss: 0.0376 | Val Loss: 0.5603 | Val Acc: 0.9413 | Val ROC AUC: 0.6675
# Epoch 94/100 | Train Loss: 0.0428 | Val Loss: 0.5389 | Val Acc: 0.9444 | Val ROC AUC: 0.6808
# Epoch 95/100 | Train Loss: 0.0396 | Val Loss: 0.5366 | Val Acc: 0.9428 | Val ROC AUC: 0.6702
# Epoch 96/100 | Train Loss: 0.0334 | Val Loss: 0.5408 | Val Acc: 0.9382 | Val ROC AUC: 0.6660
# Epoch 97/100 | Train Loss: 0.0325 | Val Loss: 0.5643 | Val Acc: 0.9366 | Val ROC AUC: 0.6620
# Epoch 98/100 | Train Loss: 0.0274 | Val Loss: 0.5936 | Val Acc: 0.9413 | Val ROC AUC: 0.6487
# Epoch 99/100 | Train Loss: 0.0343 | Val Loss: 0.5644 | Val Acc: 0.9397 | Val ROC AUC: 0.6656
# Epoch 100/100 | Train Loss: 0.0259 | Val Loss: 0.5979 | Val Acc: 0.9428 | Val ROC AUC: 0.6556

# %%
X_test_np = preprocessor.transform(test[X_vars])
y_test_np = test[target].to_numpy()

X_test = torch.tensor(X_test_np, dtype=torch.float32)
y_test = torch.tensor(y_test_np, dtype=torch.float32).view(-1, 1)

test_ds = TensorDataset(X_test, y_test)
test_loader = DataLoader(test_ds, batch_size=256, shuffle=False)

test_loss, test_acc, test_auc = evaluate_model(model, test_loader, criterion, device)
print(f"Test Loss: {test_loss:.4f} | Test Acc: {test_acc:.4f} | Test ROC AUC: {test_auc:.4f}")
# Out:
# Test Loss: 0.8152 | Test Acc: 0.9276 | Test ROC AUC: 0.6029
